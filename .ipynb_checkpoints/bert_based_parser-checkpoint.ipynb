# %%
import json
import sys
sys.path.append('../')

from KAIST_frame_parser.src import dataio, etri
from KAIST_frame_parser.src import targetid
import torch
from torch import nn
import os
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()

from KAIST_frame_parser.koreanframenet.src import conll2textae
from KAIST_frame_parser.koreanframenet import koreanframenet

from pprint import pprint
# Out:
# Using TensorFlow backend.
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# ### Korean FrameNet ###
# 	# contact: hahmyg@kaist, hahmyg@gmail.com #

# %%
language = 'en'
version = 1.7
if language == 'en':
    framenet = 'fn'+str(version)
    fn_dir = '/disk_4/resource/fn'+str(version)
    trn, dev, tst = dataio.load_fn_data(fn_dir)
elif language == 'ko':
    framenet = 'kfn'+str(version)
    kfn = koreanframenet.interface(version=version)
    trn, dev, tst = kfn.load_data()
    
try:
    target_dir = os.path.dirname(os.path.abspath( __file__ ))
except:
    target_dir = '.'
    
# save your model to
model_dir = target_dir+'/models/'+framenet+'/'
result_dir = target_dir+'/result/'

# %%
print(trn[0])
# Out:
# [['Paula_Zahn', ':', 'Questions', 'about', 'the', 'facts', 'or', 'what', 'were', 'presented', 'as', 'facts', 'that', 'led', 'the', 'United', 'States', 'into', 'the', 'war', 'in', 'Iraq', 'spilled', 'into', 'open', 'warfare', 'today', 'on', 'the', 'Senate', 'floor', '.'], ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', 'spill.v', '_', '_', '_', '_', '_', '_', '_', '_', '_'], ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', 'Fluidic_motion', '_', '_', '_', '_', '_', '_', '_', '_', '_'], ['O', 'O', 'B-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'I-Fluid', 'O', 'B-Goal', 'I-Goal', 'I-Goal', 'B-Time', 'B-Place', 'I-Place', 'I-Place', 'I-Place', 'O']]

# %%
try:
    target_dir = os.path.dirname(os.path.abspath( __file__ ))
except:
    target_dir = '.'
data_path = target_dir+'/koreanframenet/resource/info/'
with open(data_path+framenet+'_lu2idx.json','r') as f:
    lu2idx = json.load(f)
with open(data_path+'fn1.7_frame2idx.json','r') as f:
    frame2idx = json.load(f)      
with open(data_path+framenet+'_lufrmap.json','r') as f:
    lufrmap = json.load(f)
with open(data_path+'fn1.7_fe2idx.json','r') as f:
    arg2idx = json.load(f)
idx2frame = dict(zip(frame2idx.values(),frame2idx.keys()))
idx2lu = dict(zip(lu2idx.values(),lu2idx.keys()))
idx2arg = dict(zip(arg2idx.values(),arg2idx.keys()))

# %%
try:
    dir_path = os.path.dirname( os.path.abspath( __file__ ))
except:
    dir_path = '.'

# %%
class for_BERT():
    
    def __init__(self, mode='training', language='ko', version=1.0):
        version = str(version)
        self.mode = mode
        if language == 'en':
            data_path = dir_path+'/../koreanframenet/resource/info/fn'+version+'_'
        else:
            data_path = dir_path+'/../koreanframenet/resource/info/kfn'+version+'_'
        with open(data_path+'lu2idx.json','r') as f:
            self.lu2idx = json.load(f)
        with open(dir_path+'/../koreanframenet/resource/info/fn1.7_frame2idx.json','r') as f:
            #self.sense2idx = json.load(f)
            self.frame2idx = json.load(f)
        with open(data_path+'lufrmap.json','r') as f:
            #self.lusensemap = json.load(f)
            self.lufrmap = json.load(f)
        with open(dir_path+'/../koreanframenet/resource/info/fn1.7_fe2idx.json','r') as f:
            self.arg2idx = json.load(f)
        with open(dir_path+'/../koreanframenet/resource/info/fn1.7_frargmap.json','r') as f:
            self.frargmap = json.load(f)
        with open(dir_path+'/../koreanframenet/resource/info/fn1.7_bio_fe2idx.json','r') as f:
            self.bio_arg2idx = json.load(f)
        with open(dir_path+'/../koreanframenet/resource/info/fn1.7_bio_frargmap.json','r') as f:
            self.bio_frargmap = json.load(f)

        self.idx2frame = dict(zip(self.frame2idx.values(),self.frame2idx.keys()))
        self.idx2lu = dict(zip(self.lu2idx.values(),self.lu2idx.keys()))
        self.idx2arg = dict(zip(self.arg2idx.values(),self.arg2idx.keys()))
        self.idx2bio_arg = dict(zip(self.bio_arg2idx.values(),self.bio_arg2idx.keys()))

        # load pretrained BERT tokenizer
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased', do_lower_case=False)
        
        # load BERT tokenizer with untokenizing frames
        never_split_tuple = ("[UNK]", "[SEP]", "[PAD]", "[CLS]", "[MASK]")
        added_never_split = []
        added_never_split.append('<tgt>')
        for frame in self.frame2idx:
            added_never_split.append('['+frame+']')
        added_never_split_tuple = tuple(added_never_split)
        never_split_tuple += added_never_split_tuple
        vocab_file_path = dir_path+'/../data/bert-multilingual-cased-dict-with-frame'
        self.tokenizer_with_frame = BertTokenizer(vocab_file_path, do_lower_case=False, never_split=never_split_tuple)

    def idx2tag(self, predictions, model='frameid'):
        if model == 'frameid':
            pred_tags = [self.idx2frame[p_i] for p in predictions for p_i in p]
        elif model == 'argclassification':
            pred_tags = [self.idx2arg[p_i] for p in predictions for p_i in p]
        elif model == 'argid':
            pred_tags = [self.idx2bio_arg[p_i] for p in predictions for p_i in p]
        return pred_tags
    
    def get_masks(self, datas, model='frameid'):
        if model == 'frameid':
            mapdata = self.lufrmap
            num_label = len(self.frame2idx)
        elif model == 'argclassification':
            mapdata = self.frargmap
            num_label = len(self.arg2idx)
        elif model = 'argid':
            mapdata = self.bio_frargmap
            num_label = len(self.bio_arg2idx)
        masks = []
        for idx in datas:
            mask = torch.zeros(num_label)
            try:
                candis = mapdata[str(int(idx[0]))]
            except KeyboardInterrupt:
                raise
            except:
                candis = mapdata[int(idx[0])]
            for candi_idx in candis:
                mask[candi_idx] = 1
            masks.append(mask)
        masks = torch.stack(masks)
        return masks
    
    
    # bert tokenizer and assign to the first token
    def bert_tokenizer(self, text):
        orig_tokens = text.split(' ')
        bert_tokens = []
        orig_to_tok_map = []
        bert_tokens.append("[CLS]")
        for orig_token in orig_tokens:
            orig_to_tok_map.append(len(bert_tokens))
            bert_tokens.extend(self.tokenizer.tokenize(orig_token))
        bert_tokens.append("[SEP]")

        return orig_tokens, bert_tokens, orig_to_tok_map
    
    # bert tokenizer and assign to the last token
    def bert_tokenizer_assign_to_last_token(self, text):
        orig_tokens = text.split(' ')
        bert_tokens = []
        orig_to_tok_map = []
        bert_tokens.append("[CLS]")
        for orig_token in orig_tokens:
            bert_tokens.extend(self.tokenizer.tokenize(orig_token))
            orig_to_tok_map.append(len(bert_tokens)-1)
        bert_tokens.append("[SEP]")

        return orig_tokens, bert_tokens, orig_to_tok_map
    
    def bert_tokenizer_with_frame(self, text, frame):
        orig_tokens = text.split(' ')
        bert_tokens = []
        orig_to_tok_map = []
        bert_tokens.append("[CLS]")
        for orig_token in orig_tokens:
            bert_tokens.extend(self.tokenizer_with_frame.tokenize(orig_token))
            orig_to_tok_map.append(len(bert_tokens)-1)
        bert_tokens.append("[SEP]")
    
    def convert_to_bert_input_argid(self, input_data):
        tokenized_texts, lus, frames, args = [],[],[],[]

        for i in range(len(input_data)):    
            data = input_data[i]
            text = ' '.join(data[0])
            orig_tokens, bert_tokens, orig_to_tok_map = self.bert_tokenizer_assign_to_last_token(text)
            tokenized_texts.append(bert_tokens)

            ori_lus = data[1]    
            lu_sequence = []
            for i in range(len(bert_tokens)):
                if i in orig_to_tok_map:
                    idx = orig_to_tok_map.index(i)
                    l = ori_lus[idx]
                    lu_sequence.append(l)
                else:
                    lu_sequence.append('_')
            lus.append(lu_sequence)        

            ori_frames = data[2]    
            frame_sequence = []
            for i in range(len(bert_tokens)):
                if i in orig_to_tok_map:
                    idx = orig_to_tok_map.index(i)
                    l = ori_frames[idx]
                    frame_sequence.append(l)
                else:
                    frame_sequence.append('_')
            frames.append(frame_sequence)
            
            if self.mode == 'training':
                ori_args = data[3]    
                arg_sequence = []
                for i in range(len(bert_tokens)):
                    if i in orig_to_tok_map:
                        idx = orig_to_tok_map.index(i)
                        l = ori_args[idx]
                        arg_sequence.append(l)
                    else:
                        arg_sequence.append('O')
                args.append(arg_sequence)

        input_ids = pad_sequences([self.tokenizer.convert_tokens_to_ids(txt) for txt in tokenized_texts],
                              maxlen=MAX_LEN, dtype="long", truncating="post", padding="post")

        tgt_seq, lu_seq, frame_seq, arg_idx_seq, arg_seq = [],[],[],[],[]
        for sent_idx in range(len(lus)):
            lu_items = lus[sent_idx]
            tgt,lu = [],[]
            for idx in range(len(lu_items)):
                if lu_items[idx] != '_':
                    if len(tgt) == 0:
                        tgt.append(idx)
                        lu.append(self.lu2idx[lu_items[idx]])
            tgt_seq.append(tgt)
            lu_seq.append(lu)

            frame_items = frames[sent_idx]
            frame = []
            for idx in range(len(frame_items)):
                if frame_items[idx] != '_':
                    if len(frame) == 0:
                        frame.append(self.frame2idx[frame_items[idx]])
            frame_seq.append(frame)
                
            if self.mode == 'training':
                arg_items = args[sent_idx]
                arg, arg_idx = [],[]
                for idx in range(len(arg_items)):
                    if arg_items[idx] != 'O':
                        if len(arg) == 0:
                            try:
                                arg.append(self.arg2idx[arg_items[idx]])
                                arg_idx.append(idx)
                            except KeyboardInterrupt:
                                raise
                            except:
                                print(arg_items[idx])
                arg_seq.append(arg)
                arg_idx_seq.append(arg_idx)
            
            

        attention_masks = [[float(i>0) for i in ii] for ii in input_ids]    
        data_inputs = torch.tensor(input_ids)
        data_tgt_idx = torch.tensor(tgt_seq)
        data_lus = torch.tensor(lu_seq)
        data_frames = torch.tensor(frame_seq)
        data_arg_idxs = torch.tensor(arg_idx_seq)
        data_args = torch.tensor(arg_seq)
        data_masks = torch.tensor(attention_masks)
        
        if self.mode == 'training':
            bert_inputs = TensorDataset(data_inputs, data_tgt_idx, data_lus, data_frames, data_arg_idxs, data_args, data_masks)
        else:
            bert_inputs = TensorDataset(data_inputs, data_tgt_idx, data_lus, data_frames, data_masks)
        return bert_inputs

# %% [markdown]
# # gen BERT input representation

# %%
print('generate BERT input representation ...')
bert_io = dataio.for_BERT(mode='training', language=language, version=version)

trn_data = bert_io.convert_to_bert_input_arg_classifier(trn)
trn_sampler = RandomSampler(trn_data)
trn_dataloader = DataLoader(trn_data, sampler=trn_sampler, batch_size=batch_size)

dev_data = bert_io.convert_to_bert_input_arg_classifier(dev)
dev_sampler = RandomSampler(dev_data)
dev_dataloader = DataLoader(dev_data, sampler=dev_sampler, batch_size=batch_size)

tst_data = bert_io.convert_to_bert_input_arg_classifier(tst)
tst_sampler = RandomSampler(tst_data)
tst_dataloader = DataLoader(tst_data, sampler=tst_sampler, batch_size=batch_size)
print('... is done')
# Out:
# generate BERT input representation ...
# B-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# I-Fluid
# B-Goal
# I-Goal
# I-Goal
# B-Time
# B-Place
# I-Place
# I-Place
# I-Place
# B-Manner
# B-Place
# I-Place
# B-Figure
# I-Figure
# B-Ground
# B-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# B-Theme
# B-Cotheme
# I-Cotheme
# I-Cotheme
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Descriptor
# B-Part
# B-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Time
# B-Ground
# I-Ground
# I-Ground
# B-Agent
# B-Theme
# I-Theme
# B-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# B-Container_portal
# B-Descriptor
# B-Part
# B-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# B-Message
# I-Message
# I-Message
# I-Message
# B-Victim
# I-Victim
# B-Governed
# B-Leader
# I-Leader
# B-Assailant
# B-Manner
# B-Sender
# I-Sender
# I-Sender
# I-Sender
# B-Sender
# B-Theme
# I-Theme
# B-Goal
# I-Goal
# I-Goal
# B-Item
# B-Theme
# I-Theme
# B-Path
# B-Leader
# B-Act
# I-Act
# B-Origin
# B-Person
# B-Cognizer
# B-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# B-Speaker
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Origin
# B-Entity
# B-Descriptor
# B-Building
# B-Place
# I-Place
# B-Information
# B-Agent
# I-Agent
# I-Agent
# B-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# B-Descriptor
# B-Leader
# I-Leader
# B-Figure
# I-Figure
# B-Ground
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Color
# B-Entity
# B-Agent
# B-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# B-Communicator
# I-Communicator
# I-Communicator
# I-Communicator
# B-Evaluee
# B-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# B-Investigator
# B-Incident
# I-Incident
# I-Incident
# I-Incident
# I-Incident
# I-Incident
# I-Incident
# I-Incident
# I-Incident
# I-Incident
# I-Incident
# I-Incident
# B-Trajector_event
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Entity
# B-Final_quality
# I-Final_quality
# I-Final_quality
# B-Leader
# B-Activity
# B-Interlocutors
# I-Interlocutors
# B-Phenomenon
# B-Law
# B-Whole
# B-Building_part
# B-Experiencer
# I-Experiencer
# I-Experiencer
# I-Experiencer
# B-Descriptor
# B-Leader
# I-Leader
# B-Descriptor
# B-Leader
# B-Experiencer
# I-Experiencer
# I-Experiencer
# I-Experiencer
# I-Experiencer
# I-Experiencer
# I-Experiencer
# B-Trajector_entity
# I-Trajector_entity
# B-Focal_participant
# I-Focal_participant
# B-Institution
# B-Descriptor
# B-Leader
# B-Victim
# B-Body_part
# I-Body_part
# I-Body_part
# B-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# B-Dimension
# B-Object
# B-Body_part
# B-Class
# I-Class
# I-Class
# I-Class
# B-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# B-Time
# I-Time
# I-Time
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Landmark_event
# I-Landmark_event
# B-Part
# B-Whole
# I-Whole
# I-Whole
# B-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# B-Time
# I-Time
# I-Time
# B-Leader
# B-Governed
# I-Governed
# B-Speaker
# B-Proposed_action
# I-Proposed_action
# I-Proposed_action
# B-Information
# B-Agent
# I-Agent
# I-Agent
# I-Agent
# I-Agent
# B-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# B-Degree
# B-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# B-Text
# B-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# B-Text
# I-Text
# I-Text
# I-Text
# B-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# B-Information
# B-Action
# I-Action
# B-Activity
# I-Activity
# B-Hindrance
# B-Path
# B-Body_part
# B-Body_part
# B-Time
# B-Perceiver_passive
# I-Perceiver_passive
# I-Perceiver_passive
# B-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# B-Person
# B-Origin
# B-Entity
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Accused
# I-Accused
# I-Accused
# I-Accused
# B-Creator
# B-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# B-Dimension
# B-Object
# I-Object
# I-Object
# I-Object
# I-Object
# B-Event
# I-Event
# I-Event
# B-Cognizer
# B-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# B-Experiencer
# B-Emotional_state
# B-Earner
# B-Earnings
# I-Earnings
# I-Earnings
# I-Earnings
# I-Earnings
# I-Earnings
# I-Earnings
# I-Earnings
# B-Precision
# B-Number
# B-Unit
# B-Denoted_quantity
# B-Reference_quantity
# I-Reference_quantity
# B-Precision
# B-Multiplier
# B-Number
# B-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# B-Precision
# B-Multiplier
# B-Number
# B-Precision
# B-Number
# B-Unit
# B-Denoted_quantity
# B-Reference_quantity
# I-Reference_quantity
# B-Victim
# I-Victim
# I-Victim
# B-Degree
# B-Factor
# B-Multiplier
# B-Number
# B-Unit
# B-Class
# I-Class
# I-Class
# I-Class
# B-Unit
# B-Topic
# I-Topic
# I-Topic
# B-Activity
# B-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# B-Proposed_action
# I-Proposed_action
# I-Proposed_action
# I-Proposed_action
# I-Proposed_action
# I-Proposed_action
# I-Proposed_action
# I-Proposed_action
# I-Proposed_action
# B-Information
# B-Leader
# B-Governed
# I-Governed
# I-Governed
# B-Agent
# B-Activity
# I-Activity
# B-Investigator
# B-Speaker
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Act
# B-Rank
# B-Judicial_body
# B-Event
# B-Phenomenon
# I-Phenomenon
# B-Characterization
# I-Characterization
# I-Characterization
# I-Characterization
# I-Characterization
# I-Characterization
# I-Characterization
# I-Characterization
# I-Characterization
# B-Hypothetical_event
# B-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# B-Leader
# B-Experiencer
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Communicator
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Protagonist
# B-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# B-Cognizer
# I-Cognizer
# I-Cognizer
# B-Time
# B-Inherent_purpose
# I-Inherent_purpose
# B-Chosen
# I-Chosen
# B-Speaker
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Degree
# B-Degree
# B-Evaluee
# B-Appraisal
# B-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# B-Appraisal
# B-Time
# B-Hypothetical_event
# B-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# B-Hypothetical_event
# I-Hypothetical_event
# B-Perceiver_passive
# B-Time
# B-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# B-Cognizer
# B-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# B-Quantity
# B-Individuals
# B-Quantity
# B-Individuals
# B-Hypothetical_event
# I-Hypothetical_event
# B-Hypothetical_event
# B-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# B-Perceiver
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Stimulus
# B-Stimulus
# B-Experiencer
# I-Experiencer
# I-Experiencer
# I-Experiencer
# B-Quantity
# I-Quantity
# B-Individuals
# I-Individuals
# B-Ailment
# B-Quantity
# B-Degree
# B-Quantity
# B-Hearer
# B-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# B-Whole
# B-Type_property
# B-Subtype
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Killer
# B-Unit
# B-Ailment
# B-Number
# B-Leader
# B-Number
# B-Descriptor
# I-Descriptor
# B-Descriptor
# I-Descriptor
# I-Descriptor
# B-Project
# B-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# B-Multiplier
# I-Multiplier
# I-Multiplier
# B-Number
# B-Unit
# B-Hypothetical_event
# I-Hypothetical_event
# B-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# B-Protection
# I-Protection
# B-Asset
# I-Asset
# I-Asset
# I-Asset
# I-Asset
# I-Asset
# I-Asset
# I-Asset
# B-Number
# B-Unit
# B-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# B-Item
# B-Enabled_situation
# I-Enabled_situation
# I-Enabled_situation
# I-Enabled_situation
# I-Enabled_situation
# I-Enabled_situation
# I-Enabled_situation
# I-Enabled_situation
# I-Enabled_situation
# I-Enabled_situation
# B-Money
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Denoted_quantity
# B-Mass
# I-Mass
# I-Mass
# B-Multiplier
# B-Number
# B-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# B-Field
# B-Employer
# B-Type
# B-Class
# I-Class
# B-Potential_hindrance
# I-Potential_hindrance
# I-Potential_hindrance
# I-Potential_hindrance
# I-Potential_hindrance
# I-Potential_hindrance
# I-Potential_hindrance
# I-Potential_hindrance
# I-Potential_hindrance
# I-Potential_hindrance
# I-Potential_hindrance
# I-Potential_hindrance
# I-Potential_hindrance
# I-Potential_hindrance
# B-Potential_hindrance
# B-Event
# I-Event
# B-Denoted_quantity
# B-Individuals
# B-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# B-Product
# I-Product
# B-Trajector_event
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Whole
# B-Superior
# I-Superior
# I-Superior
# I-Superior
# I-Superior
# I-Superior
# I-Superior
# I-Superior
# I-Superior
# I-Superior
# I-Superior
# I-Superior
# I-Superior
# I-Superior
# B-Person
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# B-Denoted_quantity
# I-Denoted_quantity
# B-Individuals
# I-Individuals
# B-Cause
# I-Cause
# B-Period_of_iterations
# I-Period_of_iterations
# I-Period_of_iterations
# I-Period_of_iterations
# I-Period_of_iterations
# B-Victim
# I-Victim
# I-Victim
# I-Victim
# B-Relative_time
# B-Count
# B-Unit
# B-Number
# B-Unit
# B-Focal_occasion
# I-Focal_occasion
# B-Ailment
# B-Part
# B-Whole
# I-Whole
# I-Whole
# I-Whole
# I-Whole
# I-Whole
# I-Whole
# B-Victim
# I-Victim
# I-Victim
# I-Victim
# B-Victim
# B-Cause
# I-Cause
# B-Mass
# I-Mass
# I-Mass
# I-Mass
# I-Mass
# I-Mass
# I-Mass
# I-Mass
# B-Quantity
# B-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# B-Ailment
# B-Goal
# I-Goal
# I-Goal
# I-Goal
# B-Victim
# I-Victim
# I-Victim
# I-Victim
# I-Victim
# I-Victim
# I-Victim
# I-Victim
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Ground
# I-Ground
# B-Quantity
# B-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# B-Figure
# I-Figure
# I-Figure
# B-Ground
# B-Place
# I-Place
# B-Building
# B-Locale
# B-Professional
# B-Evaluee
# I-Evaluee
# I-Evaluee
# B-Event
# I-Event
# I-Event
# I-Event
# B-Cognizer
# B-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# B-Cognizer
# B-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# B-Project
# B-Leader
# B-Unit
# B-Cognizer
# B-Estimation
# B-Experiencer
# B-Stimulus
# B-Degree
# I-Degree
# B-Cognizer
# B-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# B-Body_part
# B-Quantity
# B-Ground
# I-Ground
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Number
# B-Entity
# B-Leader
# B-Ailment
# B-Money
# B-Entity
# I-Entity
# B-Entity
# B-Time
# B-Place
# B-Ailment
# B-Entity
# I-Entity
# B-Time
# B-Interlocutors
# I-Interlocutors
# I-Interlocutors
# I-Interlocutors
# B-Topic
# I-Topic
# B-Quantity
# B-Quantity
# B-Individuals
# I-Individuals
# B-Person
# B-Person
# B-Quantity
# B-Quantity
# B-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# B-Cognizer
# B-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Ground
# I-Ground
# I-Ground
# I-Ground
# B-Patient
# B-Domain
# I-Domain
# B-Person
# B-Quantity
# B-Quantity
# B-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# B-Body_part
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# B-Message
# I-Message
# B-Message
# B-Message
# B-Time
# B-Locale
# B-Interlocutor_1
# I-Interlocutor_1
# B-Interlocutor_1
# B-Interlocutor_2
# I-Interlocutor_2
# I-Interlocutor_2
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Locale
# B-Interlocutor_1
# I-Interlocutor_1
# B-Interlocutor_2
# I-Interlocutor_2
# I-Interlocutor_2
# I-Interlocutor_2
# I-Interlocutor_2
# I-Interlocutor_2
# I-Interlocutor_2
# I-Interlocutor_2
# I-Interlocutor_2
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Governed
# B-Leader
# B-Class
# B-Governed
# B-Leader
# B-Function
# I-Function
# B-Complex
# B-Patient
# B-Entity
# I-Entity
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Entity
# I-Entity
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Governed
# B-Leader
# B-Aggregate
# B-Individuals
# I-Individuals
# I-Individuals
# B-Landmark_period
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Ailment
# B-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# B-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# B-Increment
# I-Increment
# B-Class
# B-Function
# I-Function
# B-Complex
# B-Degree
# B-Patient
# B-Quantity
# I-Quantity
# B-Individuals
# I-Individuals
# B-Quantity
# I-Quantity
# B-Individuals
# I-Individuals
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Ground
# I-Ground
# I-Ground
# I-Ground
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Speaker
# B-Degree
# I-Degree
# B-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Protagonist
# B-Degree
# I-Degree
# B-Degree
# B-Skill
# I-Skill
# I-Skill
# I-Skill
# I-Skill
# B-Time
# B-Degree
# I-Degree
# I-Degree
# I-Degree
# I-Degree
# I-Degree
# B-Factor
# I-Factor
# I-Factor
# B-Degree
# B-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# I-Factor
# B-Building
# B-Relative_location
# I-Relative_location
# B-Theme
# I-Theme
# B-Theme
# B-Goal
# B-Depictive
# I-Depictive
# I-Depictive
# B-Hypothetical_event
# I-Hypothetical_event
# B-Hypothetical_event
# B-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# B-Time
# I-Time
# I-Time
# I-Time
# B-Container
# I-Container
# I-Container
# I-Container
# I-Container
# I-Container
# I-Container
# I-Container
# B-Use
# B-Building_part
# B-Function
# B-Complex
# B-Topical_entity
# B-Entity
# I-Entity
# I-Entity
# B-Entity
# B-Event
# B-Intended_event
# B-Asset
# I-Asset
# I-Asset
# I-Asset
# I-Asset
# B-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# I-Intended_event
# B-Money
# B-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# B-Class
# I-Class
# I-Class
# I-Class
# I-Class
# I-Class
# B-Interlocutors
# B-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# B-Recipient
# I-Recipient
# B-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# I-Mass_theme
# B-Leader
# B-Multiplier
# B-Number
# B-Unit
# B-Project
# B-Cognizer
# B-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# B-Subtype
# B-Number
# B-Entity
# B-Entity
# I-Entity
# I-Entity
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Factor
# B-Cognizer
# B-Degree
# I-Degree
# B-Person
# B-Quantity
# I-Quantity
# B-Individuals
# I-Individuals
# B-Quantity
# I-Quantity
# B-Mass
# I-Mass
# B-Influencing_entity
# B-Agent
# I-Agent
# B-Goal
# I-Goal
# I-Goal
# I-Goal
# B-Cause
# I-Cause
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Idea
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Hypothetical_event
# I-Hypothetical_event
# B-Hypothetical_event
# I-Hypothetical_event
# B-Hypothetical_event
# I-Hypothetical_event
# B-Ailment
# B-Locale
# B-Medium
# B-Ground
# B-Cognizer
# B-Content
# I-Content
# I-Content
# I-Content
# B-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Means
# I-Means
# I-Means
# I-Means
# I-Means
# I-Means
# I-Means
# B-Ground
# B-Ailment
# B-Person
# B-Phenomenon
# B-Agent
# B-Act
# I-Act
# B-Explanation
# I-Explanation
# I-Explanation
# B-Entity
# B-Reason
# I-Reason
# I-Reason
# B-Patient
# B-Ailment
# B-Cognizer
# B-Content
# I-Content
# I-Content
# I-Content
# B-Duration
# I-Duration
# B-Vehicle
# B-Vehicle
# B-Count
# B-Unit
# B-Process
# I-Process
# B-Ailment
# B-Speaker
# B-Addressee
# B-Message
# B-Entity
# B-Event
# I-Event
# I-Event
# B-Constituent_parts
# B-Food
# B-Food
# B-Information
# B-Message
# B-Speaker
# I-Speaker
# B-Professional
# B-Time
# I-Time
# I-Time
# B-Agent
# B-Place
# B-Professional
# B-Intended_event
# I-Intended_event
# B-Building
# B-Unit
# B-Vehicle
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Person
# B-Descriptor
# B-Vehicle
# B-Source
# I-Source
# I-Source
# I-Source
# I-Source
# B-Age
# B-Person
# B-Locale
# B-Weapon
# B-Perceiver
# I-Perceiver
# B-Sought_entity
# I-Sought_entity
# I-Sought_entity
# I-Sought_entity
# I-Sought_entity
# B-Location
# I-Location
# I-Location
# B-Governed
# B-Vehicle
# B-Content
# B-Cognizer
# B-Content
# I-Content
# B-Building
# B-Vehicle
# B-Item
# I-Item
# I-Item
# B-Speaker
# B-Resident
# I-Resident
# I-Resident
# I-Resident
# I-Resident
# I-Resident
# I-Resident
# B-Location
# B-Perceiver
# I-Perceiver
# B-Sought_entity
# I-Sought_entity
# B-Location
# I-Location
# I-Location
# B-Speaker
# B-Residents
# B-Weapon
# B-Person
# B-Descriptor
# I-Descriptor
# I-Descriptor
# I-Descriptor
# I-Descriptor
# B-Perceiver_passive
# B-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# B-Building
# B-Cognizer
# B-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# B-Perceiver
# B-Agent
# I-Agent
# B-Created_entity
# I-Created_entity
# B-Weapon
# B-Leader
# B-Building
# B-Person
# B-Descriptor
# B-Descriptor
# B-Locale
# B-Document
# B-Sought_entity
# B-Location
# I-Location
# I-Location
# I-Location
# B-Medium
# I-Medium
# I-Medium
# I-Medium
# I-Medium
# I-Medium
# B-Unconfirmed_content
# I-Unconfirmed_content
# I-Unconfirmed_content
# I-Unconfirmed_content
# I-Unconfirmed_content
# I-Unconfirmed_content
# I-Unconfirmed_content
# I-Unconfirmed_content
# I-Unconfirmed_content
# I-Unconfirmed_content
# B-Protagonist
# B-Document
# B-Agent
# I-Agent
# I-Agent
# I-Agent
# I-Agent
# B-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# B-Resource
# B-Product
# I-Product
# B-Resource
# B-Weapon
# B-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# B-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# B-Cognizer
# B-Name
# I-Name
# B-Locale
# B-Message
# I-Message
# I-Message
# B-Speaker
# I-Speaker
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Governed
# B-Weapon
# I-Weapon
# B-Material
# B-Name
# I-Name
# I-Name
# I-Name
# I-Name
# I-Name
# B-Locale
# B-Speaker
# I-Speaker
# B-Addressee
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Theme
# I-Theme
# I-Theme
# B-Source
# I-Source
# I-Source
# I-Source
# I-Source
# I-Source
# I-Source
# I-Source
# B-Governed
# I-Governed
# B-Leader
# B-Speaker
# I-Speaker
# I-Speaker
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Shape_prop
# B-Shape
# B-Type
# B-Type
# B-Weapon
# I-Weapon
# B-Name
# B-Use
# I-Use
# I-Use
# I-Use
# I-Use
# I-Use
# I-Use
# I-Use
# B-Result
# I-Result
# I-Result
# B-Weapon
# B-Descriptor
# B-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# B-Entities
# B-Fuel
# B-Fire
# B-Fire
# I-Fire
# B-Place
# I-Place
# B-Event
# I-Event
# B-Event
# I-Event
# B-Place
# I-Place
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Time
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Landmark_period
# B-Destroyer
# I-Destroyer
# I-Destroyer
# B-Destroyer
# B-Patient
# I-Patient
# I-Patient
# I-Patient
# I-Patient
# I-Patient
# I-Patient
# B-Container_possessor
# B-Locale
# B-Name
# I-Name
# B-Count
# I-Count
# I-Count
# I-Count
# B-Unit
# B-Occupant
# I-Occupant
# B-Fire
# I-Fire
# I-Fire
# I-Fire
# I-Fire
# I-Fire
# I-Fire
# I-Fire
# I-Fire
# I-Fire
# I-Fire
# I-Fire
# I-Fire
# B-Place
# I-Place
# I-Place
# I-Place
# I-Place
# I-Place
# B-Fuel
# B-Fire
# B-Degree
# B-Reference_quantity
# I-Reference_quantity
# B-Individuals
# B-Reference_occasion
# I-Reference_occasion
# I-Reference_occasion
# I-Reference_occasion
# B-Reference_occasion
# I-Reference_occasion
# B-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# B-Organization
# B-Fire
# B-Protagonist
# I-Protagonist
# B-Time
# I-Time
# B-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# B-Flame
# I-Flame
# B-Flame
# B-Manner
# B-Kindler
# I-Kindler
# B-Time
# I-Time
# I-Time
# I-Time
# B-Perpetrator
# B-Message
# I-Message
# B-Message
# B-Speaker
# I-Speaker
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Kindler
# I-Kindler
# I-Kindler
# B-Flame
# I-Flame
# B-Authorities
# B-Suspect
# I-Suspect
# I-Suspect
# B-Charges
# I-Charges
# I-Charges
# I-Charges
# I-Charges
# I-Charges
# B-Person
# B-Age
# I-Age
# B-Person
# B-Total
# I-Total
# I-Total
# B-Part
# I-Part
# I-Part
# I-Part
# B-Suspect
# B-Act
# B-Agent
# B-Cognizer
# B-Cognizer
# B-Content
# I-Content
# I-Content
# I-Content
# B-Place
# I-Place
# B-Descriptor
# B-Organization
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# B-Role
# B-Governed
# I-Governed
# I-Governed
# I-Governed
# I-Governed
# B-Leader
# I-Leader
# I-Leader
# B-Flame
# B-Time
# B-Flame
# I-Flame
# I-Flame
# B-Theme
# B-Direction
# B-Goal
# I-Goal
# I-Goal
# B-Purpose
# I-Purpose
# I-Purpose
# B-Cognizer
# B-Cognizer
# B-Content
# I-Content
# I-Content
# I-Content
# I-Content
# B-Trajector
# B-Landmark
# I-Landmark
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Landmark_period
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Figure
# I-Figure
# I-Figure
# B-Time
# B-Ground
# I-Ground
# I-Ground
# B-Person
# B-Descriptor
# B-Locale
# B-Protection
# I-Protection
# I-Protection
# B-Asset
# I-Asset
# B-Asset
# B-Asset
# I-Asset
# B-Use
# B-Locale
# B-Building
# B-Relative_location
# B-Locale
# B-Governed
# I-Governed
# B-Domain
# I-Domain
# B-Leader
# I-Leader
# I-Leader
# I-Leader
# B-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# B-Time
# I-Time
# I-Time
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Locale
# B-Helper
# I-Helper
# I-Helper
# I-Helper
# I-Helper
# B-Benefited_party
# I-Benefited_party
# I-Benefited_party
# B-Employer
# B-Employee
# B-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# B-Path
# B-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# B-Manner
# B-Agent
# I-Agent
# I-Agent
# I-Agent
# I-Agent
# I-Agent
# B-Time
# B-Event
# B-Event
# I-Event
# I-Event
# B-Fire
# B-Quantity
# B-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# B-Leader
# I-Leader
# B-Place
# B-Type
# I-Type
# B-Circumstances
# I-Circumstances
# I-Circumstances
# I-Circumstances
# B-Circumstances
# B-Degree
# B-Comparison_set
# I-Comparison_set
# I-Comparison_set
# B-Owner
# B-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# B-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# B-Agent
# B-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# B-Weapon
# B-Instrument
# B-Evaluee
# B-Frequency
# B-Communicator
# I-Communicator
# I-Communicator
# B-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# B-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# B-Aggregate_property
# B-Aggregate
# B-Weapon
# B-Means
# B-Time
# B-Addressee
# I-Addressee
# I-Addressee
# I-Addressee
# B-Medium
# I-Medium
# I-Medium
# I-Medium
# I-Medium
# I-Medium
# I-Medium
# I-Medium
# B-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Activity
# I-Activity
# B-Owner
# B-Possession
# I-Possession
# I-Possession
# I-Possession
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Direction
# B-Landmark_event
# I-Landmark_event
# I-Landmark_event
# B-Cognizer
# B-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# B-Container
# B-Contents
# I-Contents
# I-Contents
# I-Contents
# I-Contents
# I-Contents
# I-Contents
# B-Supply
# B-Resource
# I-Resource
# I-Resource
# I-Resource
# I-Resource
# B-Type
# B-Substance
# B-Type
# B-Weapon
# B-Ratifier
# B-Proposal
# I-Proposal
# I-Proposal
# I-Proposal
# I-Proposal
# I-Proposal
# I-Proposal
# I-Proposal
# I-Proposal
# B-Subtype
# B-Category
# I-Category
# I-Category
# I-Category
# I-Category
# I-Category
# I-Category
# I-Category
# B-Communicator
# B-Manner
# B-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# B-Degree
# B-Entity
# I-Entity
# B-Descriptor
# I-Descriptor
# B-Activity
# B-Artifact
# B-Owner
# B-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# B-Employee
# B-Descriptor
# B-Use
# B-Locale
# B-Student
# B-Total
# I-Total
# I-Total
# I-Total
# I-Total
# I-Total
# B-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# B-Item
# I-Item
# B-Current_country
# B-Topic
# B-Interlocutor_2
# I-Interlocutor_2
# I-Interlocutor_2
# B-Protagonist
# B-Participant_1
# B-Event
# I-Event
# I-Event
# I-Event
# B-Participant_2
# I-Participant_2
# I-Participant_2
# B-Current_country
# B-Experiencer
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Type
# B-Substance
# B-Descriptor
# B-Source
# B-Recipient
# B-Theme
# I-Theme
# B-Source
# I-Source
# I-Source
# B-Supplier
# B-Recipient
# B-Imposed_purpose
# I-Imposed_purpose
# I-Imposed_purpose
# I-Imposed_purpose
# I-Imposed_purpose
# I-Imposed_purpose
# I-Imposed_purpose
# I-Imposed_purpose
# I-Imposed_purpose
# I-Imposed_purpose
# I-Imposed_purpose
# I-Imposed_purpose
# I-Imposed_purpose
# B-Type
# I-Type
# I-Type
# I-Type
# I-Type
# I-Type
# B-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# I-Speaker
# B-Manner
# B-Time
# I-Time
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Purpose
# I-Purpose
# I-Purpose
# B-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# B-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# B-Origin
# B-Entity
# B-Created_entity
# B-Creator
# B-Recipient
# I-Recipient
# B-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# B-Cognizer_agent
# I-Cognizer_agent
# B-Sought_entity
# I-Sought_entity
# I-Sought_entity
# I-Sought_entity
# I-Sought_entity
# I-Sought_entity
# I-Sought_entity
# I-Sought_entity
# I-Sought_entity
# I-Sought_entity
# B-Origin
# B-Entity
# B-Employee
# B-Origin
# I-Origin
# I-Origin
# B-Person
# B-Origin
# B-Entity
# B-Content
# I-Content
# B-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# B-Cause
# B-Product
# I-Product
# I-Product
# I-Product
# B-Speaker
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Created_entity
# B-Creator
# I-Creator
# I-Creator
# B-Source
# B-Recipient
# B-Theme
# I-Theme
# I-Theme
# B-Instrument
# I-Instrument
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Circumstances
# I-Circumstances
# I-Circumstances
# I-Circumstances
# I-Circumstances
# I-Circumstances
# I-Circumstances
# I-Circumstances
# B-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# B-Possessor
# I-Possessor
# B-Descriptor
# B-Activity
# I-Activity
# I-Activity
# B-Phenomenon
# I-Phenomenon
# B-Artifact
# B-Salient_entity
# B-Artifact
# B-Name
# B-Locale
# B-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# B-Importing_area
# I-Importing_area
# B-Exporting_area
# I-Exporting_area
# I-Exporting_area
# B-Number
# B-Entity
# B-Goal
# B-Cognizer
# I-Cognizer
# I-Cognizer
# B-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# B-Agent
# B-Project
# I-Project
# I-Project
# B-Time
# I-Time
# I-Time
# I-Time
# I-Time
# I-Time
# I-Time
# I-Time
# I-Time
# I-Time
# I-Time
# B-Experience
# B-Experience
# I-Experience
# I-Experience
# I-Experience
# I-Experience
# I-Experience
# I-Experience
# I-Experience
# I-Experience
# I-Experience
# I-Experience
# I-Experience
# I-Experience
# I-Experience
# I-Experience
# B-Source
# B-Agent
# B-Salient_entity
# B-Activity
# B-Goal
# B-Descriptor
# I-Descriptor
# I-Descriptor
# B-Substance
# B-Action
# I-Action
# B-Goal
# B-Item
# I-Item
# B-Number
# B-Entity
# B-Entity
# I-Entity
# I-Entity
# I-Entity
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Artifact
# B-Action
# I-Action
# I-Action
# I-Action
# I-Action
# I-Action
# I-Action
# B-Total
# I-Total
# I-Total
# I-Total
# I-Total
# I-Total
# I-Total
# I-Total
# I-Total
# B-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# B-Creator
# B-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# B-Agent
# B-Salient_entity
# B-Creator
# B-Created_entity
# I-Created_entity
# B-Locale
# B-Weapon
# B-Protagonist
# B-Substance
# B-Owner
# B-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# B-Authority
# I-Authority
# I-Authority
# I-Authority
# I-Authority
# I-Authority
# I-Authority
# B-Helper
# I-Helper
# I-Helper
# I-Helper
# I-Helper
# I-Helper
# I-Helper
# I-Helper
# B-Benefited_party
# I-Benefited_party
# I-Benefited_party
# I-Benefited_party
# B-Creator
# I-Creator
# I-Creator
# I-Creator
# I-Creator
# I-Creator
# I-Creator
# I-Creator
# B-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Artifact
# B-Type_property
# B-Subtype
# B-Activity
# B-Agent
# B-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# B-Project
# I-Project
# B-Time
# I-Time
# I-Time
# B-Evaluee
# B-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# I-Reason
# B-Category
# I-Category
# I-Category
# B-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# B-Instrument
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Buyer
# B-Seller
# I-Seller
# I-Seller
# I-Seller
# I-Seller
# B-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# I-Goods
# B-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# B-Subtype
# B-Origin
# B-Entity
# B-Person
# B-Agent
# B-Instrument
# I-Instrument
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# B-Action
# I-Action
# B-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# B-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# I-Content
# B-Subtype
# B-Goal
# B-Speaker
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# B-Manner
# I-Manner
# I-Manner
# I-Manner
# I-Manner
# I-Manner
# I-Manner
# B-Scale
# B-Enabled_situation
# I-Enabled_situation
# I-Enabled_situation
# I-Enabled_situation
# I-Enabled_situation
# B-Subtype
# B-Category
# I-Category
# B-Substance
# I-Substance
# I-Substance
# I-Substance
# I-Substance
# I-Substance
# I-Substance
# I-Substance
# I-Substance
# I-Substance
# I-Substance
# I-Substance
# I-Substance
# I-Substance
# I-Substance
# B-Descriptor
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Speaker
# B-Entity
# B-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# B-Cause
# I-Cause
# I-Cause
# B-Descriptor
# B-Function
# B-Complex
# B-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# B-Recipient
# I-Recipient
# B-Theme
# I-Theme
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Agent
# I-Agent
# B-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# B-Arguer
# I-Arguer
# B-Goal
# B-Instrument
# B-Purpose
# B-Hypothetical_event
# I-Hypothetical_event
# B-Degree
# B-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# B-Accoutrement
# B-Accoutrement
# B-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# B-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# B-Material
# I-Material
# I-Material
# I-Material
# I-Material
# B-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# B-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# B-Purpose
# I-Purpose
# B-Agent
# I-Agent
# I-Agent
# I-Agent
# I-Agent
# I-Agent
# B-Time
# I-Time
# I-Time
# I-Time
# I-Time
# I-Time
# B-Artifact
# B-Place
# B-Business
# B-Employee
# I-Employee
# I-Employee
# B-Task
# I-Task
# I-Task
# I-Task
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Type
# B-Weapon
# B-Employee
# I-Employee
# I-Employee
# B-Employer
# I-Employer
# B-Task
# I-Task
# I-Task
# I-Task
# I-Task
# I-Task
# I-Task
# B-Descriptor
# B-Substance
# B-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# B-Cause
# B-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# B-Recipient
# B-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# B-Speaker
# I-Speaker
# B-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# B-Experiencer
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Researcher
# B-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# B-Product
# I-Product
# I-Product
# B-Instrument
# I-Instrument
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Descriptor
# B-Substance
# B-Agent
# B-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# B-Text
# B-Descriptor
# B-Type
# B-Substance
# B-Degree
# B-Cause
# I-Cause
# B-Researcher
# B-Manner
# B-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# I-Topic
# B-Communicator
# I-Communicator
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# B-Source
# B-Specified_entity
# I-Specified_entity
# I-Specified_entity
# B-Speaker
# I-Speaker
# I-Speaker
# B-Source
# B-Type
# B-Substance
# B-Phenomenon
# B-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# B-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# B-Point_of_view
# I-Point_of_view
# I-Point_of_view
# I-Point_of_view
# B-Substance
# I-Substance
# B-Descriptor
# B-Effect
# I-Effect
# B-Agent
# B-Salient_entity
# B-Substance
# B-Phenomenon
# B-Cause
# B-Effect
# I-Effect
# B-Possession
# I-Possession
# B-Owner
# B-Weapon
# B-Part_prop
# I-Part_prop
# B-Part
# B-Content
# I-Content
# I-Content
# I-Content
# I-Content
# B-Content
# B-Content
# I-Content
# B-Theme
# I-Theme
# I-Theme
# I-Theme
# B-Type
# B-Substance
# B-Entity
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Protagonist
# B-Type
# B-Substance
# B-Deliverer
# B-Theme
# I-Theme
# B-Vehicle
# I-Vehicle
# I-Vehicle
# I-Vehicle
# I-Vehicle
# I-Vehicle
# I-Vehicle
# I-Vehicle
# I-Vehicle
# I-Vehicle
# B-Agent
# B-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# B-Type
# B-Weapon
# B-Type
# B-Substance
# B-Speaker
# I-Speaker
# B-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# B-Owner
# B-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# I-Possession
# B-Individuals
# B-Individuals
# B-Means
# I-Means
# I-Means
# I-Means
# I-Means
# B-Type
# B-Weapon
# B-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# B-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# I-Reported_fact
# B-Entity
# I-Entity
# I-Entity
# I-Entity
# B-Event
# I-Event
# I-Event
# I-Event
# B-Carrier
# I-Carrier
# I-Carrier
# I-Carrier
# B-Theme
# I-Theme
# B-Agent
# B-Act
# I-Act
# I-Act
# I-Act
# I-Act
# I-Act
# B-Weapon
# B-Type
# B-Weapon
# B-Weapon
# B-Weapon
# B-Assailant
# I-Assailant
# I-Assailant
# B-Agent
# B-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# I-Project
# B-Agent
# B-Occasion
# I-Occasion
# I-Occasion
# I-Occasion
# B-Manner
# B-Action
# B-Means
# I-Means
# I-Means
# B-Force
# B-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# B-Producer
# B-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# I-Product
# B-Person
# B-Aggregate
# B-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# B-Salient_entity
# B-Item
# I-Item
# B-Limits_of_consideration
# I-Limits_of_consideration
# I-Limits_of_consideration
# I-Limits_of_consideration
# I-Limits_of_consideration
# I-Limits_of_consideration
# I-Limits_of_consideration
# B-Locale
# I-Locale
# I-Locale
# I-Locale
# I-Locale
# I-Locale
# I-Locale
# I-Locale
# I-Locale
# I-Locale
# I-Locale
# B-Relative_location
# B-Product
# I-Product
# B-Concept_2
# B-Concept_1
# B-Entity
# I-Entity
# B-Name
# I-Name
# I-Name
# I-Name
# I-Name
# I-Name
# I-Name
# B-Organization
# B-Organization
# I-Organization
# I-Organization
# I-Organization
# I-Organization
# I-Organization
# I-Organization
# I-Organization
# I-Organization
# I-Organization
# B-Organization
# B-Topic
# I-Topic
# B-Person
# B-Artifact
# B-Time
# I-Time
# I-Time
# B-Creator
# B-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# I-Created_entity
# ...
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# I-Evaluee
# B-Goods
# B-Seller
# B-Manipulator
# I-Manipulator
# B-Victim
# I-Victim
# B-Degree
# I-Degree
# I-Degree
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Medium
# I-Medium
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Text
# B-Subpart
# I-Subpart
# B-Dimension
# B-Object
# B-Agent
# B-Goal
# I-Goal
# B-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# B-Agent
# B-Victim
# I-Victim
# I-Victim
# I-Victim
# I-Victim
# B-Authorities
# B-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# B-Genre
# B-Text
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Ground
# I-Ground
# B-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Medium
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Behavior
# I-Behavior
# I-Behavior
# I-Behavior
# I-Behavior
# I-Behavior
# I-Behavior
# B-Degree
# I-Degree
# B-Current_country
# B-Ground
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Message
# I-Message
# I-Message
# B-Speaker
# I-Speaker
# I-Speaker
# B-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# B-Figures
# I-Figures
# I-Figures
# I-Figures
# I-Figures
# I-Figures
# I-Figures
# I-Figures
# I-Figures
# I-Figures
# I-Figures
# I-Figures
# I-Figures
# I-Figures
# I-Figures
# I-Figures
# B-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# I-Ground
# B-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# I-Concept_1
# B-Concept_2
# I-Concept_2
# I-Concept_2
# I-Concept_2
# I-Concept_2
# I-Concept_2
# I-Concept_2
# B-Number
# B-Entity
# B-Descriptor
# I-Descriptor
# B-Locale
# B-Item
# I-Item
# I-Item
# I-Item
# I-Item
# I-Item
# I-Item
# I-Item
# I-Item
# I-Item
# I-Item
# I-Item
# B-Type
# I-Type
# I-Type
# I-Type
# I-Type
# I-Type
# I-Type
# B-Event
# B-Specified_entity
# I-Specified_entity
# I-Specified_entity
# B-Specified_entity
# I-Specified_entity
# I-Specified_entity
# I-Specified_entity
# I-Specified_entity
# I-Specified_entity
# I-Specified_entity
# B-Themes
# B-Hypothetical_event
# B-Time
# B-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# B-Individual_1
# B-Individual_2
# I-Individual_2
# B-Cognizer
# B-Action
# I-Action
# I-Action
# I-Action
# B-Ego
# I-Ego
# B-Alter
# B-Agent
# I-Agent
# I-Agent
# B-Theme
# I-Theme
# B-Agent
# I-Agent
# I-Agent
# B-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# B-Descriptor
# B-Combatant
# B-Ground
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Side
# B-Side
# B-Cognizer
# B-Degree
# B-Total
# I-Total
# I-Total
# I-Total
# I-Total
# I-Total
# I-Total
# I-Total
# I-Total
# I-Total
# I-Total
# B-Part
# B-Phenomenon
# I-Phenomenon
# B-Phenomenon
# B-Locale
# B-Destroyer
# I-Destroyer
# I-Destroyer
# B-Patient
# B-Agent
# I-Agent
# B-Act
# I-Act
# I-Act
# I-Act
# B-Descriptor
# B-Leader
# B-Role
# I-Role
# I-Role
# I-Role
# I-Role
# B-Participants
# I-Participants
# B-Event
# I-Event
# I-Event
# I-Event
# B-Charges
# B-Place
# I-Place
# B-Figure
# I-Figure
# B-Ground
# B-Case
# B-Defendant
# I-Defendant
# I-Defendant
# I-Defendant
# I-Defendant
# I-Defendant
# I-Defendant
# I-Defendant
# B-Event
# I-Event
# B-Name
# I-Name
# B-Organization
# B-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# I-Cause
# B-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# I-Effect
# B-Exchangers
# I-Exchangers
# B-Themes
# B-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# I-Cognizer
# B-Constancy
# I-Constancy
# I-Constancy
# B-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# I-Opinion
# B-Unit
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Speaker
# B-Addressee
# I-Addressee
# I-Addressee
# I-Addressee
# I-Addressee
# B-Time
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Organization
# B-Controlling_entity
# I-Controlling_entity
# B-Governed
# B-Leader
# B-Organization
# B-Agent
# I-Agent
# B-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# I-Goal
# B-Manipulator
# I-Manipulator
# B-Victim
# I-Victim
# I-Victim
# B-Resulting_action
# I-Resulting_action
# B-Side_2
# I-Side_2
# I-Side_2
# I-Side_2
# B-Place
# I-Place
# B-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# I-Activity
# B-Message
# I-Message
# I-Message
# B-Message
# I-Message
# I-Message
# I-Message
# I-Message
# I-Message
# B-Time
# I-Time
# B-Authorities
# I-Authorities
# B-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# B-Organization
# B-Type
# B-Governed
# B-Leader
# B-Leader
# B-Relative_time
# B-Unit
# B-Topic
# B-Process
# I-Process
# I-Process
# B-Agent
# I-Agent
# I-Agent
# B-Hypothetical_event
# I-Hypothetical_event
# B-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# B-Suspect
# B-Crime_jurisdiction
# I-Crime_jurisdiction
# I-Crime_jurisdiction
# B-Purpose
# I-Purpose
# B-Legal_basis
# I-Legal_basis
# I-Legal_basis
# I-Legal_basis
# I-Legal_basis
# I-Legal_basis
# I-Legal_basis
# I-Legal_basis
# I-Legal_basis
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Class
# I-Class
# B-Theme
# I-Theme
# I-Theme
# I-Theme
# B-Weapon
# B-Count
# B-Unit
# B-Stuff
# I-Stuff
# B-Time
# B-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# I-Suspect
# B-Seller
# I-Seller
# B-Force
# B-Speaker
# I-Speaker
# I-Speaker
# B-Proposal
# I-Proposal
# I-Proposal
# B-Benefited_party
# I-Benefited_party
# I-Benefited_party
# B-Helper
# B-Domain
# B-Intoxicant
# B-Domain
# B-Situation
# B-Party_1
# I-Party_1
# B-Time
# I-Time
# I-Time
# B-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# I-Party_2
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Landmark_period
# I-Landmark_period
# B-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# I-Trajector_event
# B-Leader
# B-Party_1
# I-Party_1
# B-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# I-Obligation
# B-Leader
# I-Leader
# I-Leader
# B-Governed
# I-Governed
# B-Interlocutor_1
# I-Interlocutor_1
# B-Topic
# I-Topic
# I-Topic
# B-Count
# B-Unit
# B-Leader
# I-Leader
# B-Governed
# I-Governed
# B-Act
# B-Time
# I-Time
# I-Time
# I-Time
# I-Time
# B-Event
# I-Event
# B-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# B-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# B-Mass
# B-Cognizer
# B-Requirement
# I-Requirement
# B-Experiencer
# B-Landmark_event
# I-Landmark_event
# I-Landmark_event
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Patient
# B-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# I-Hypothetical_event
# B-Cognizer
# I-Cognizer
# I-Cognizer
# B-Degree
# B-Dependent
# I-Dependent
# B-Differentiating_fact
# I-Differentiating_fact
# I-Differentiating_fact
# I-Differentiating_fact
# I-Differentiating_fact
# I-Differentiating_fact
# I-Differentiating_fact
# I-Differentiating_fact
# B-Entities
# I-Entities
# I-Entities
# I-Entities
# I-Entities
# I-Entities
# I-Entities
# I-Entities
# B-Time
# I-Time
# I-Time
# I-Time
# B-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# I-Instrument
# B-Agent
# B-Locale
# B-Use
# I-Use
# I-Use
# B-Created_entity
# I-Created_entity
# I-Created_entity
# B-Creator
# I-Creator
# I-Creator
# I-Creator
# I-Creator
# I-Creator
# I-Creator
# I-Creator
# B-Information
# B-Source
# I-Source
# I-Source
# I-Source
# I-Source
# I-Source
# I-Source
# I-Source
# I-Source
# I-Source
# I-Source
# I-Source
# I-Source
# B-Genre
# B-Text
# B-Descriptor
# B-Locale
# B-Entity
# B-Descriptor
# B-Locale
# B-Topic
# B-Information
# B-Consideration
# I-Consideration
# I-Consideration
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Text
# B-Time_of_creation
# I-Time_of_creation
# I-Time_of_creation
# I-Time_of_creation
# B-Donor
# I-Donor
# I-Donor
# B-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# I-Theme
# B-Quantity
# B-Individuals
# I-Individuals
# B-Degree
# B-Differentiating_fact
# I-Differentiating_fact
# I-Differentiating_fact
# I-Differentiating_fact
# I-Differentiating_fact
# B-Time
# I-Time
# I-Time
# I-Time
# B-Entity
# B-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# B-Entity
# I-Entity
# B-Count
# B-Unit
# B-Value
# B-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# B-Genre
# B-Text
# B-Time_of_creation
# I-Time_of_creation
# I-Time_of_creation
# I-Time_of_creation
# B-Q_prop
# B-Quantity
# B-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# B-Donor
# I-Donor
# I-Donor
# I-Donor
# I-Donor
# B-Recipient
# I-Recipient
# I-Recipient
# I-Recipient
# I-Recipient
# I-Recipient
# I-Recipient
# B-Period_of_iterations
# I-Period_of_iterations
# I-Period_of_iterations
# I-Period_of_iterations
# B-Number
# B-Unit
# B-Text
# B-Value
# B-Attribute
# I-Attribute
# I-Attribute
# B-Unit
# B-Whole
# B-Entity
# B-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# I-Purpose
# B-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# I-Phenomenon
# B-Domain
# B-Degree
# B-Phenomenon
# B-Endeavor
# I-Endeavor
# I-Endeavor
# B-Determinant
# B-Number
# B-Entity
# I-Entity
# B-Unit
# B-Whole
# B-Precision
# B-Number
# B-Entity
# I-Entity
# B-Degree
# B-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# B-Total
# I-Total
# I-Total
# I-Total
# I-Total
# I-Total
# B-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# I-Part
# B-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# I-Explanation
# B-Text
# B-Value
# B-Attribute
# I-Attribute
# I-Attribute
# B-Text
# B-Text
# B-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# B-Means
# I-Means
# I-Means
# I-Means
# I-Means
# B-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# B-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# I-Figure
# B-Ground
# I-Ground
# B-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# B-Speed
# I-Speed
# I-Speed
# B-Place
# I-Place
# I-Place
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Degree
# B-Rate
# B-Number
# B-Entity
# I-Entity
# B-Degree
# B-Entity
# I-Entity
# I-Entity
# I-Entity
# I-Entity
# B-Attribute
# I-Attribute
# I-Attribute
# B-Duration
# I-Duration
# I-Duration
# B-Quantity
# B-Mass
# I-Mass
# I-Mass
# I-Mass
# I-Mass
# I-Mass
# I-Mass
# B-Quantity
# B-Individuals
# I-Individuals
# I-Individuals
# I-Individuals
# B-Money
# B-Inherent_purpose
# I-Inherent_purpose
# I-Inherent_purpose
# I-Inherent_purpose
# I-Inherent_purpose
# B-Increment
# B-Class
# B-Text
# B-Number
# B-Entity
# I-Entity
# I-Entity
# B-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# I-Support
# B-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# I-Proposition
# B-Locale
# B-Output
# B-Time
# I-Time
# I-Time
# B-Inherent_purpose
# B-Money
# B-Person
# B-Quantity
# B-Mass
# I-Mass
# I-Mass
# I-Mass
# I-Mass
# I-Mass
# B-Quantity
# B-Mass
# I-Mass
# I-Mass
# I-Mass
# I-Mass
# I-Mass
# I-Mass
# B-Text
# B-Number
# B-Entity
# I-Entity
# B-Descriptor
# B-Locale
# B-Entity
# B-Money
# B-Inherent_purpose
# I-Inherent_purpose
# I-Inherent_purpose
# I-Inherent_purpose
# I-Inherent_purpose
# B-Asset
# I-Asset
# I-Asset
# I-Asset
# B-Origin
# I-Origin
# I-Origin
# I-Origin
# B-Degree
# B-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# I-Attribute
# B-Place
# I-Place
# I-Place
# B-Intended_event
# I-Intended_event
# B-Determinant
# B-Fact
# I-Fact
# B-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# I-State_of_affairs
# B-Increment
# B-Class
# I-Class
# B-Person
# B-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# I-Event
# B-Direction
# B-Distance
# I-Distance
# I-Distance
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-be9dc104c4b3> in <module>()
#       2 bert_io = dataio.for_BERT(mode='training', language=language, version=version)
#       3
# ----> 4 trn_data = bert_io.convert_to_bert_input_arg_classifier(trn)
#       5 trn_sampler = RandomSampler(trn_data)
#       6 trn_dataloader = DataLoader(trn_data, sampler=trn_sampler, batch_size=batch_size)
#
# /disk_4/KAIST_frame_parser/src/dataio.py in convert_to_bert_input_arg_classifier(self, input_data)
#     339         data_lus = torch.tensor(lu_seq)
#     340         data_frames = torch.tensor(frame_seq)
# --> 341         data_arg_idxs = torch.tensor(arg_idx_seq)
#     342         data_args = torch.tensor(arg_seq)
#     343         data_masks = torch.tensor(attention_masks)
#
# RuntimeError: sizes must be non-negative
